# %% [markdown]
# ## Load Data

# %%
# enable many obj dumps in a cell w/out print - not used this wk
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pandas as pd
pd.set_option('display.max_columns', None)

df = pd.read_csv("data.csv")
#print(df)
#df.tail(2)

# %% [markdown]
# ## Clean up and rename

# %%
# Explicit dictionary mapping: original column name → desired column name
explicit_column_map = {
    "X": "x",
    "Y": "y",
    "OBJECTID": "object_id",
    "Incidentid": "incident_id",
    "DateTime": "date_time",
    "Year": "year",
    "StreetName": "street_name",
    "CrossStreet": "cross_street",
    "Distance": "distance",
    "JunctionRelation": "junction_relation",
    "Totalinjuries": "total_injuries",
    "Totalfatalities": "total_fatalities",
    "Injuryseverity": "injury_severity",
    "Collisionmanner": "collision_manner",
    "Lightcondition": "light_condition",
    "Weather": "weather",
    "SurfaceCondition": "surface_condition",
    "Unittype_One": "unit_type_1",
    "Age_Drv1": "age_1",
    "Gender_Drv1": "gender_1",
    "Traveldirection_One": "travel_direction_1",
    "Unitaction_One": "unit_action_1",
    "Violation1_Drv1": "violation_1",
    "AlcoholUse_Drv1": "alcohol_use_1",
    "DrugUse_Drv1": "drug_use_1",
    "Unittype_Two": "unit_type_2",
    "Age_Drv2": "age_2",
    "Gender_Drv2": "gender_2",
    "Traveldirection_Two": "travel_direction_2",
    "Unitaction_Two": "unit_action_2",
    "Violation1_Drv2": "violation_2",
    "AlcoholUse_Drv2": "alcohol_use_2",
    "DrugUse_Drv2": "drug_use_2",
    "Latitude": "lat",
    "Longitude": "long"
}

# Rename using the dictionary
df.rename(columns=explicit_column_map, inplace=True)
df.tail(2)
# Out:
#                 x          y  object_id  incident_id               date_time  \
# 51303 -111.926404  33.435576      51304    4155885.0  2024/03/14 13:20:00+00
# 51304 -111.909869  33.436621      51305    4155890.0  2024/03/15 07:11:00+00
#
#          year           street_name cross_street  distance  \
# 51303  2024.0  SR-202 Exit 7 T-Ramp          NaN       0.0
# 51304  2024.0  SR-202 Exit 8 J-Ramp          NaN       0.0
#
#             junction_relation  total_injuries  total_fatalities  \
# 51303  Entrance Exit Ramp 205             0.0               0.0
# 51304  Entrance Exit Ramp 205             0.0               0.0
#
#       injury_severity collision_manner light_condition weather  \
# 51303       No Injury         Rear End        Daylight   Clear
# 51304       No Injury   Single Vehicle    Dark Lighted   Clear
#
#       surface_condition unit_type_1  age_1 gender_1 travel_direction_1  \
# 51303               Dry      Driver   40.0     Male               East
# 51304               Dry      Driver   26.0     Male              North
#
#            unit_action_1                   violation_1          alcohol_use_1  \
# 51303  Making Right Turn          Followed Too Closely  No Apparent Influence
# 51304   Making Left Turn  Speed To Fast For Conditions  No Apparent Influence
#
#                   drug_use_1 unit_type_2  age_2 gender_2 travel_direction_2  \
# 51303  No Apparent Influence      Driver   25.0   Female               West
# 51304  No Apparent Influence         NaN    NaN      NaN                NaN
#
#            unit_action_2         violation_2          alcohol_use_2  \
# 51303  Making Right Turn  No Improper Action  No Apparent Influence
# 51304                NaN                 NaN                    NaN
#
#                   drug_use_2        lat        long
# 51303  No Apparent Influence  33.435576 -111.926404
# 51304                    NaN  33.436621 -111.909869

# %%
# Convert types with error handling and timezone removal for datetime
df['date_time'] = pd.to_datetime(df['date_time'], errors='coerce').dt.tz_localize(None)

# Type conversion map
dtype_map = {
    'x': 'float',
    'y': 'float',
    'object_id': 'Int64',
    'incident_id': 'Int64',
    'year': 'Int64',
    'street_name': 'string',
    'cross_street': 'string',
    'distance': 'float',
    'junction_relation': 'string',
    'total_injuries': 'Int64',
    'total_fatalities': 'Int64',
    'injury_severity': 'string',
    'collision_manner': 'string',
    'light_condition': 'string',
    'weather': 'string',
    'surface_condition': 'string',
    'unit_type_1': 'string',
    'age_1': 'Int64',
    'gender_1': 'string',
    'travel_direction_1': 'string',
    'unit_action_1': 'string',
    'violation_1': 'string',
    'alcohol_use_1': 'string',
    'drug_use_1': 'string',
    'unit_type_2': 'string', 
    'age_2': 'Int64',
    'gender_2': 'string',
    'travel_direction_2': 'string',
    'unit_action_2': 'string',
    'violation_2': 'string',
    'alcohol_use_2': 'string',
    'drug_use_2': 'string',
    'lat': 'float',
    'long': 'float'
}

# Apply conversions
for col, dtype in dtype_map.items():
    df[col] = df[col].astype(dtype, errors='ignore')

df.dtypes
# Out:
# x                            float64
# y                            float64
# object_id                      Int64
# incident_id                    Int64
# date_time             datetime64[ns]
# year                           Int64
# street_name                   string
# cross_street                  string
# distance                     float64
# junction_relation             string
# total_injuries                 Int64
# total_fatalities               Int64
# injury_severity               string
# collision_manner              string
# light_condition               string
# weather                       string
# surface_condition             string
# unit_type_1                   string
# age_1                          Int64
# gender_1                      string
# travel_direction_1            string
# unit_action_1                 string
# violation_1                   string
# alcohol_use_1                 string
# drug_use_1                    string
# unit_type_2                   string
# age_2                          Int64
# gender_2                      string
# travel_direction_2            string
# unit_action_2                 string
# violation_2                   string
# alcohol_use_2                 string
# drug_use_2                    string
# lat                          float64
# long                         float64
# dtype: object

# %%
df
# Out:
#                 x          y  object_id  incident_id           date_time  \
# 0     -111.952210  33.421910          1      2598369 2012-01-01 07:25:00
# 1     -111.937690  33.423190          2      2593420 2012-01-01 11:45:00
# 2     -111.891960  33.418420          3      2588493 2012-01-01 18:07:00
# 3     -111.947910  33.417790          4      2584449 2012-01-02 00:03:00
# 4     -111.928470  33.349560          5      2592211 2012-01-02 00:12:00
# ...           ...        ...        ...          ...                 ...
# 51300 -111.939524  33.386046      51301      4155893 2024-03-09 07:44:00
# 51301 -111.972540  33.409359      51302      4154752 2024-03-11 20:30:00
# 51302 -111.926385  33.435558      51303      4155884 2024-03-14 13:15:00
# 51303 -111.926404  33.435576      51304      4155885 2024-03-14 13:20:00
# 51304 -111.909869  33.436621      51305      4155890 2024-03-15 07:11:00
#
#        year            street_name cross_street  distance  \
# 0      2012          University Dr     Hardy Dr     0.000
# 1      2012                 7th St   Myrtle Ave   139.920
# 2      2012               Price Rd    Orange St     0.000
# 3      2012                11th St      Judd St   200.112
# 4      2012               Rural Rd    Elliot Rd   135.168
# ...     ...                    ...          ...       ...
# 51300  2024  US-60 Exit 173 J-Ramp         <NA>     0.000
# 51301  2024  I-10 Exit 153 C1-Ramp         <NA>     0.000
# 51302  2024   SR-202 Exit 7 T-Ramp         <NA>     0.000
# 51303  2024   SR-202 Exit 7 T-Ramp         <NA>     0.000
# 51304  2024   SR-202 Exit 8 J-Ramp         <NA>     0.000
#
#                           junction_relation  total_injuries  total_fatalities  \
# 0              Intersection Non Interchange               6                 0
# 1                      Not Junction Related               0                 0
# 2                  Intersection Interchange               0                 0
# 3                      Not Junction Related               0                 0
# 4      Intersection Related Non Interchange               1                 0
# ...                                     ...             ...               ...
# 51300                Entrance Exit Ramp 205               0                 0
# 51301                  Not Junction Related               0                 0
# 51302                  Not Junction Related               1                 0
# 51303                Entrance Exit Ramp 205               0                 0
# 51304                Entrance Exit Ramp 205               0                 0
#
#                  injury_severity                             collision_manner  \
# 0      Non Incapacitating Injury  ANGLE (Front To Side)(Other Than Left Turn)
# 1                      No Injury                               Single Vehicle
# 2                      No Injury                                    Left Turn
# 3                      No Injury                 Sideswipe Opposite Direction
# 4                Possible Injury                     Sideswipe Same Direction
# ...                          ...                                          ...
# 51300                  No Injury                               Single Vehicle
# 51301                  No Injury                     Sideswipe Same Direction
# 51302            Possible Injury                                     Rear End
# 51303                  No Injury                                     Rear End
# 51304                  No Injury                               Single Vehicle
#
#       light_condition weather surface_condition unit_type_1  age_1 gender_1  \
# 0        Dark Lighted   Clear               Dry      Driver     23   Female
# 1        Dark Lighted   Clear               Dry      Driver    255     <NA>
# 2            Daylight   Clear               Dry      Driver     26     Male
# 3            Daylight   Clear               Dry      Driver    255     <NA>
# 4                Dusk   Clear               Dry      Driver     59     Male
# ...               ...     ...               ...         ...    ...      ...
# 51300    Dark Lighted   Clear               Dry      Driver     25     Male
# 51301        Daylight   Clear               Dry      Driver     20     Male
# 51302        Daylight   Clear               Dry      Driver     35     Male
# 51303        Daylight   Clear               Dry      Driver     40     Male
# 51304    Dark Lighted   Clear               Dry      Driver     26     Male
#
#       travel_direction_1      unit_action_1                   violation_1  \
# 0                   West   Making Left Turn       Inattention Distraction
# 1                   East            Backing                       Unknown
# 2                  South   Making Left Turn            Made Improper Turn
# 3                Unknown            Unknown                       Unknown
# 4                  South     Changing Lanes            Unsafe Lane Change
# ...                  ...                ...                           ...
# 51300              South  Making Right Turn  Speed To Fast For Conditions
# 51301               East  Making Right Turn  Failed To Yield Right Of Way
# 51302               East      Making U Turn  Speed To Fast For Conditions
# 51303               East  Making Right Turn          Followed Too Closely
# 51304              North   Making Left Turn  Speed To Fast For Conditions
#
#                alcohol_use_1             drug_use_1 unit_type_2  age_2  \
# 0                    Alcohol  No Apparent Influence      Driver     20
# 1      No Apparent Influence  No Apparent Influence        <NA>   <NA>
# 2      No Apparent Influence  No Apparent Influence      Driver     31
# 3      No Apparent Influence  No Apparent Influence  Driverless   <NA>
# 4      No Apparent Influence  No Apparent Influence      Driver     20
# ...                      ...                    ...         ...    ...
# 51300                Alcohol  No Apparent Influence        <NA>   <NA>
# 51301  No Apparent Influence  No Apparent Influence      Driver     31
# 51302  No Apparent Influence  No Apparent Influence      Driver     22
# 51303  No Apparent Influence  No Apparent Influence      Driver     25
# 51304  No Apparent Influence  No Apparent Influence        <NA>   <NA>
#
#       gender_2 travel_direction_2          unit_action_2         violation_2  \
# 0       Female               East   Going Straight Ahead  No Improper Action
# 1         <NA>               <NA>                   <NA>                <NA>
# 2         Male              South   Going Straight Ahead  No Improper Action
# 3         <NA>               East        Properly Parked                <NA>
# 4       Female              South   Going Straight Ahead  No Improper Action
# ...        ...                ...                    ...                 ...
# 51300     <NA>               <NA>                   <NA>                <NA>
# 51301   Female               East      Making Right Turn  Unsafe Lane Change
# 51302   Female               East  Stopped In Trafficway  No Improper Action
# 51303   Female               West      Making Right Turn  No Improper Action
# 51304     <NA>               <NA>                   <NA>                <NA>
#
#                alcohol_use_2             drug_use_2        lat        long
# 0      No Apparent Influence  No Apparent Influence  33.421910 -111.952210
# 1                       <NA>                   <NA>  33.423190 -111.937690
# 2      No Apparent Influence  No Apparent Influence  33.418420 -111.891960
# 3                       <NA>                   <NA>  33.417790 -111.947910
# 4      No Apparent Influence  No Apparent Influence  33.349560 -111.928470
# ...                      ...                    ...        ...         ...
# 51300                   <NA>                   <NA>  33.386046 -111.939524
# 51301  No Apparent Influence  No Apparent Influence  33.409359 -111.972540
# 51302  No Apparent Influence  No Apparent Influence  33.435558 -111.926385
# 51303  No Apparent Influence  No Apparent Influence  33.435576 -111.926404
# 51304                   <NA>                   <NA>  33.436621 -111.909869
#
# [51305 rows x 35 columns]

# %%
# List distinct values in the 'injury_severity' column
distinct_injury_severity = df['injury_severity'].dropna().unique()
distinct_injury_severity.tolist()

# Define the standardization map for injury severity
severity_mapping = {
    "No Injury": "None",
    "Possible Injury": "Minor",
    "Non Incapacitating Injury": "Minor",
    "Suspected Minor Injury": "Minor",
    "Incapacitating Injury": "Severe",
    "Suspected Serious Injury": "Severe",
    "Fatal": "Severe"
}

# Apply the mapping to create a new column
df["severity_class"] = df["injury_severity"].map(severity_mapping)
# Out:
# ['Non Incapacitating Injury',
#  'No Injury',
#  'Possible Injury',
#  'Incapacitating Injury',
#  'Fatal',
#  'Suspected Serious Injury',
#  'Suspected Minor Injury']
