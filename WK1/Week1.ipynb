# %% [markdown]
# # 1. Getting Started

# %% [markdown]
# ## Shortcut keys for working in Jupyter Notebooks:
#
# #### Essential Jupyter Notebook Shortcuts
#
# - **Enter**: Enter edit mode for the selected cell.
# - **Esc**: Exit edit mode, entering command mode.
# - **Shift + Enter**: Run the current cell and move to the next cell.
# - **Ctrl + Enter**: Run the current cell and remain in the same cell.
# - **Alt + Enter**: Run the current cell and insert a new cell below.
# - **Up/Down Arrows**: Navigate up or down through cells.
# - **A**: Insert a new cell above the current cell (in command mode).
# - **B**: Insert a new cell below the current cell (in command mode).
# - **D, D** (press D twice): Delete the current cell.
# - **M**: Change the current cell to Markdown type.
# - **Y**: Change the current cell to Code type.
# - **Z**: Undo the last cell deletion.
# - **Shift + M**: Merge selected cells, or current cell with cell below if only one cell is selected.
# - **Ctrl + S**: Save and checkpoint the notebook.

# %% [markdown]
# # 2. Markdown Basics
# (double-click on this cell so you can see the markdown)
#
# # Header1
#
# ## Header2
#
# ### A Smaller Header
#
# Ordered Lists:
# 1. List Item 1
# 2. Item 2
# 3. Item 3
#
# Unordered Lists:
# * Item 1
# * Item 2
# * Thing 3
#
# **This is bolded text** <br>
# <br>
# <br>
# <br>
# <br>
# *This is italicized text*
#
# ## How do we embed an external link?
# (double click on this cell to see markdown below)
#
# [The ultimate guide to Markdown](https://www.kaggle.com/code/cuecacuela/the-ultimate-markdown-cheat-sheet)
#
#
# ## How do we link to an external image?
# (double click on this cell to see markdown below)
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/1*PzzcJA-cwXQ8hwlpM4DwbA@2x.jpeg">

# %% [markdown]
# ## How to embed a local image?
# 1. Click on "Edit" dropdown menu above
# 2. Scroll to the bottom of the menu
# 3. Click on "Insert Image" and then select an image on your hard-drive
#
# > Note: the following image will **NOT** render when you run this markdown cell because the image tag is pointing to a file that is NOT stored on your computer.  To test out this functionality.  Delete the image tag below and try embedding your own locally stored image using the "edit" dropdown menu at the top of the notebook (look for the 'insert image' option)
#
# ![Firefly%20black%20and%20white%20sketch%20of%20a%20beer%20drinking%20cat%20445.jpg](attachment:Firefly%20black%20and%20white%20sketch%20of%20a%20beer%20drinking%20cat%20445.jpg)

# %% [markdown]
# # 3. Print Statements
#
# ### Questions to consider
#
# 1. Why do so many introductions to coding languages begin with print statements?
#     * e.g. print("Hello World!")
# 2. What's the big deal about seeing a collection of words displayed directly below a code cell where those same words are included in a print request?
# 3. How do practitioners use print() statements in the real world?
# 4. How do I handle complext print statements?
#     > - e.g. when statements include apostraphes
#     > - long statements that need multiple lines
#     > - situations where I want to incorporate dynamic information?

# %% [markdown]
# # Try ALL of the following and take notes on the questions

# %% [markdown]
# ### Run the next 4 code cells - why do some of them NOT work?

# %%
print("I love rock and roll!")
# Out:
# I love rock and roll!

# %%
Print("I love rock and roll")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Print("I love rock and roll")
#
# NameError: name 'Print' is not defined

# %%
PRINT("I love rock and roll")

# %%
print('I love rock and roll!')

# %% [markdown]
# ### Telling Python to skip certain characters

# %%
# Run this code cell - you will get an error - do you know why?
print('I'm excited to learn Python')

# %%
# This next option should work - how is this different than the cell above?
print("I'm excited to learn Python")

# %% [markdown]
# > Run the next few code cells and take note of the results - are you taking note of what the variations in syntax are doing?

# %%
# Question: what is the backslash symbol below doing for us?
print('I\'m excited to learn Python')

# %%
print('\"I\'m excited to learn Python!\"')

# %% [markdown]
# ### Printing long statements
#
# > Run each of the code cells below - take note of the differences in each print() <br>
# statement an the resulting output.<br>
# Note that not ALL of the print() statements will run without error.

# %%
print("Beavers build dams and lodges using tree branches, vegetation, rocks and mud; they chew down trees for building material. Dams restrict water flow, and lodges serve as shelters. Their infrastructure creates wetlands used by many other species, and because of their effect on other organisms in the ecosystem, beavers are considered a keystone species. Adult males and females live in monogamous pairs with their offspring. After their first year, the young help their parents repair dams and lodges; older siblings may also help raise newly-born offspring.")

# %%
print("Beavers build dams and lodges using tree branches, vegetation, rocks and mud. 
      They chew down trees for building material. Dams restrict water flow, and lodges serve as shelters. 
      Their infrastructure creates wetlands used by many other species, 
      and because of their effect on other organisms in the ecosystem, 
      beavers are considered a keystone species. 
      Adult males and females live in monogamous pairs with their offspring. 
      After their first year, the young help their parents repair dams and lodges; 
      older siblings may also help raise newly-born offspring.")

# %%
print("Beavers build dams and lodges using tree branches, vegetation, rocks and mud. \
      They chew down trees for building material. Dams restrict water flow, and lodges serve as shelters. \
      Their infrastructure creates wetlands used by many other species,\
      and because of their effect on other organisms in the ecosystem, \
      beavers are considered a keystone species. \
      Adult males and females live in monogamous pairs with their offspring. \
      After their first year, the young help their parents repair dams and lodges; \
      older siblings may also help raise newly-born offspring.")

# %%
print("Beavers build dams and lodges using tree branches, vegetation, rocks and mud.\n\
They chew down trees for building material.\n\
Dams restrict water flow, and lodges serve as shelters.\n\
Their infrastructure creates wetlands used by many other species,\n\
and because of their effect on other organisms in the ecosystem,\n\
beavers are considered a keystone species.\n\
Adult males and females live in monogamous pairs with their offspring.\n\
After their first year, the young help their parents repair dams and lodges;\n\
older siblings may also help raise newly-born offspring.")

# %%
print("""
Beavers build dams and lodges using tree branches,vegetation, rocks and mud. 
They chew down trees for building material.
Dams restrict water flow, and lodges serve as shelters.
Their infrastructure creates wetlands used by many other species,
and because of their effect on other organisms in the ecosystem,
beavers are considered a keystone species. 
Adult males and females live in monogamous pairs with their offspring. 
After their first year, the young help their parents repair dams and lodges; 
older siblings may also help raise newly-born offspring.
""")

# %% [markdown]
# ### More complex printing

# %%
print("I love rock and roll!"*5)

# %%
print("I love rock and roll" + "I love rock and roll" + "I love rock and roll")

# %%
print("I love rock and roll!\n"*5)

# %%
print("How many Foo Fighters albums are there? ", 10)

# %%
print("What am I doing?")
print()
print("What am I doing",end='?')

# %%
print("I'm so confused. What am I doing",end='?'*5)

# %%
print('_'*60)
print('+'*60)
print("THIS IS AN IMPORTANT MESSAGE",end='!'*10)
print("\nI hope you got that")
print('_'*60)
print('+'*60)

# %%
print("Hi there how are you")
print()
print("Hi","there","how","are","you")

# %%
print("\"Hello!!!\"","I have",20,"students in class!")

# %%
# One way to print vertically oriented info
print("Apples: ",10,
      "\nOranges: ",20,
      "\nGrapes: ",28
     )
print()

# Another way to print the same thing
print("Apples: ",10)
print("Oranges: ", 20,)
print("Grapes: ",28)

# %% [markdown]
# ### Looking Ahead - Dynamic Printing Using Variables
#
# #### Notes:
# > 1. I see an "import" statement

# %%
import random

template = """
There was a young man from {place},
Who {activity} his {item} {with_something}.
  One night after dark,
  {it_did_something} {in_a_place},
And he never worked out {reason}.
"""

print(template)

# %%
# A single syllable and must rhyme with the "with_something" items.
selected_place = random.choice(
    ["Tashkent", "Trent", "Kent", "Ghent", ]
)  

# two syllables.
selected_activity = random.choice(
    ["wrapped up", "covered", "painted", "fastened", ]  
)

# single syllable.
item = random.choice(
    ["head", "hand", "dog", "foot", ]  
)

# Three syllables and must rhyme with the "place" items.
with_something = random.choice(
    ["in a tent", "with cement", "with some scent", "that was bent", ]  
)

# Three (ish) syllables.
it_did_something = random.choice(
    ["It ran off", "It glowed", "It blew up", "It turned blue", ]  
)

# Three syllables and must rhyme with the word, "dark".
in_a_place = random.choice(
    ["in the park", "like a quark", "for a lark", "with a bark", ]  
)

# Three syllables.
reason = random.choice(
    ["where it went", "its intent", "why it went", "what it meant", ]  
)

limerick = template.format(
    place=selected_place,
    activity=selected_activity,
    item=item,
    with_something=with_something,
    it_did_something=it_did_something,
    in_a_place=in_a_place,
    reason=reason,
)
print(limerick)

# %% [markdown]
# # 4. Integers
#
# ## what can we do with integers?
#
# 1. We count things
# 2. We can find things (indexing)
# 3. We can iterate over certain actions using integers

# %%
# Below are the fruit counts (bushels) for each week of the harvest
# The objects below can be updated and changed to reflect 
# current data
apples = 14
oranges = 28
grapes = 3

# Note: sometimes integers are stored in object names and used
# as "global" parameters for code functionality that is 
# further down in your code.  If these are parameters that
# occasionally need to be updated, it may be easier to 
# establish their current values AT THE TOP of your code
# and then simply refer to the object names to which those
# values are assigned further down in your code.  In cases
# like this, you may see a message in the script like the 
# one below - basically that you are free to change anything
# above this message, but nothing below - things like this
# are fairly common when working with teams and you want
# to maintain the integrity of your code.  Of course, there's
# an even better way to maintain code integrity that we will
# come to later in the course!

############################################################
# DO NOT CHANGE ANYTHING BELOW THIS LINE!!!!!!!! :(
############################################################

# Imagine some really important code here that is dependent
# on the integer parameters defined up above

# %% [markdown]
# ## Feel free to add more integer examples as seen in the recording or from your own research

# %% [markdown]
# # 5. Floats
#
# Continuous variables (NOT countable) <br>
# Discrete variables (ARE countable)
#
# ## Where will encounter float objects?
#
# 1. Scientific calcs
# 2. Financial data
# 3. Statistical analysis
# 4. Coordinate systems
# 5. Time and data calculations
# 6. A lot of measures in business

# %%
# Example float objects
x = 12.0
y = 28.9

# %% [markdown]
# >If more is covered on this topic in the recording - feel free to pause the recording and try out the code I type on your own
#
# # 6. Strings
#
# ### Creating basic string objects

# %%
string1 = "python"
string2 = 'is fun'
string3 = "I'm excited for this journey"
string4 = 'I\'m excited for this journey'

print(string1)
print(string2)
print(string3)
print(string4)

# %%
a_new_string = string1 + " " + string2
print(a_new_string)

# %%
string1 = string1.upper()
string1

# %% [markdown]
# **Strings are a sequential object**
#
# >Python starts counting at 0

# %%
print(string1[0])
print(string1[1])
print(string1[2])
print(string1[3])
print(string1[4])
print(string1[5])

# %%
print(string1[-1])

# %%
a_long_string = "Once upon a time there was a student who wanted to learn Python"

# %% [markdown]
# # What I've learned so far
#
# 1. Setup a Jupyter Notebook
# 2. Basics of Markdown
# 3. print statements
# 4. Basic Python Data Objects:
#     * integers
#     * floats
#     * strings
#     * bools
# 5. Variable naming conventions
# 6. Objects have attributes and methods
# 7. Operators
#
# # Don't forget!!! All Python objects have associated attributes and methods!!!

# %%
# if you ever forget what objects have been created
# are currently stored in memory, run the following command
# %whos
# Out:
# Interactive namespace is empty.
